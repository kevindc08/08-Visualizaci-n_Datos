# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Crea un DataFrame con el archivo de la carpeta `Data/loan.csv`, puedes encontrar más información de la data dando click [aqui](https://www.kaggle.com/datasets/sujithmandala/simple-loan-classification-dataset).

# %%
ln=pd.read_csv('Data/loan.csv')

# %% [markdown]
# # Variables:
# - `age`-Edad
# - `gender`-Genero
# - `occupation`-Ocupacion
# - `education_level`-Nivel de educacion
# - `marital_statu`-Estado civil
# - `income`-Ingreso
# - `credit_score`-Puntuaje de credito
# - `loan_status`-Estado del prestamo

# %%
ln.head(2)
# Out:
#    age  gender occupation education_level marital_status  income  \
# 0   32    Male   Engineer      Bachelor's        Married   85000
# 1   45  Female    Teacher        Master's         Single   62000
#
#    credit_score loan_status
# 0           720    Approved
# 1           680    Approved

# %%
ln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              61 non-null     int64
#  1   gender           61 non-null     object
#  2   occupation       61 non-null     object
#  3   education_level  61 non-null     object
#  4   marital_status   61 non-null     object
#  5   income           61 non-null     int64
#  6   credit_score     61 non-null     int64
#  7   loan_status      61 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 3.9+ KB

# %% [markdown]
# 2. Crea un grafico de barras en donde se muestren la cantidad de personas registradas por `occupation`.

# %%
ln['occupation'].value_counts()
# Out:
# occupation
# Engineer        5
# Analyst         2
# Chef            2
# Writer          2
# Banker          2
# Receptionist    2
# Teacher         2
# Professor       2
# Designer        2
# Marketing       2
# Salesman        2
# Architect       2
# Consultant      2
# Doctor          2
# IT              2
# Artist          2
# Lawyer          2
# Nurse           2
# Accountant      2
# Manager         2
# Photographer    1
# Server          1
# Psychologist    1
# Software        1
# Musician        1
# Dentist         1
# Programmer      1
# Editor          1
# Pilot           1
# Realtor         1
# Electrician     1
# HR              1
# Sales           1
# Veterinarian    1
# Researcher      1
# Pharmacist      1
# Student         1
# Stylist         1
# Name: count, dtype: int64

# %%
a=ln['occupation'].value_counts()
plt.figure(figsize=(10,6))  #tamaño de gráfico
plt.bar(a.index,a.values,color='red')

#añadir título y  etiquetas a los ejes.
plt.title('Profesiones de los clientes')
plt.xlabel('Profeciones')#poner etiqueta a eje x
plt.ylabel('Número de Clientes')#poner etiqueta a eje y
plt.xticks(rotation=90)
plt.show()#mostrar Gráfico

# %% [markdown]
# 3. Crea un gráfico de barras en donde se muestre el total de personar registradas por `education_level`

# %%
a=ln['education_level'].value_counts()
plt.figure(figsize=(10,6))  
plt.bar(a.index,a.values,color='yellow')
plt.title('Nivel educativo')
plt.xlabel('Profeciones')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 4. Crea un grafico circular en donde se muestre la proporcion de Hombres y mujeres de acuerdo a la columna `gender`

# %%
a=ln['gender'].value_counts()
plt.figure(figsize=(10,6))  
plt.pie (a.values,labels=a.index,colors=['blue','pink'],autopct='%1.1f%%')
plt.title('Gender')

plt.show()

# %% [markdown]
# 5. Crea un histograma con la columna `age`.

# %%
a=ln['age'].value_counts()
plt.figure(figsize=(10,6))  
plt.hist(ln['age'] ,bins=20,color='yellow',edgecolor='black')
plt.title('age')
plt.xlabel('Profeciones')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=90)
plt.show()
